# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12, 8)



#read the data 
df = pd.read_csv(r"C:\Users\user\Downloads\archive (6)\movies.csv")
#look at the data 
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#looking for data type
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#looking for the missing data 
for column in df.columns:
    missing = np.mean(df[column].isnull())
    print('{} - {}%'.format(column, missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#removing the missing value 
df.dropna(subset=["gross"], axis=0, inplace =True)

# %%
#removing the missing value 
df.dropna(subset=["budget"], axis=0, inplace =True)

# %%
#drop unnecessary column
df = df.drop(["rating"], axis =1)

# %%
#drop unnecessary column
df = df.drop(["country"], axis =1)

# %%
#drop unnecessary column
df = df.drop(["company"], axis =1)

# %%
#drop unnecessary column
df = df.drop(["runtime"], axis =1)

# %%
#looking for the missing data again
for column in df.columns:
    missing = np.mean(df[column].isnull())
    print('{} - {}%'.format(column, missing))
# Out:
# name - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# budget - 0.0%
# gross - 0.0%

# %%
df.sort_values(by=['gross'],inplace = False, ascending = False)
# Out:
#                                             name   genre  year  \
# 5445                                      Avatar  Action  2009
# 7445                           Avengers: Endgame  Action  2019
# 3045                                     Titanic   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  Action  2015
# 7244                      Avengers: Infinity War  Action  2018
# ...                                          ...     ...   ...
# 2434                  Philadelphia Experiment II  Action  1993
# 3681                                Ginger Snaps   Drama  2000
# 272                                     Parasite  Horror  1982
# 2417                                    Madadayo   Drama  1993
# 3203                                  Trojan War  Comedy  1997
#
#                                released  score      votes          director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0     James Cameron
# ...

# %%
x =df["budget"]
y =df["gross"]
plt.title('budget vs gross')
plt.xlabel('gross earing')
plt.xlabel('budget for film')
plt.scatter(x, y)

# %%
sns.regplot(x='budget', y='gross', data=df)
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12340\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#             year     score     votes    budget     gross
# year    1.000000  0.055174  0.205758  0.327781  0.274264
# score   0.055174  1.000000  0.473809  0.071792  0.222143
# votes   0.205758  0.473809  1.000000  0.440021  0.614904
# budget  0.327781  0.071792  0.440021  1.000000  0.740395
# gross   0.274264  0.222143  0.614904  0.740395  1.000000

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation matrix for numerical feature')
plt.xlabel('movie feature ')
plt.xlabel('movie feature')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12340\2828473041.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')

# %%
df_numerized = df



for col_name in df_numerized.columns:
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes

# %%
corrliation_mat = df_numerized.corr()
corr_pair = corrliation_mat.unstack()
corr_pair
# Out:
# name   name        1.000000
#        genre       0.009617
#        year        0.024435
#        released   -0.005896
#        score       0.014904
#                      ...
# gross  director   -0.013239
#        writer     -0.015009
#        star       -0.009381
#        budget      0.696424
#        gross       1.000000
# Length: 121, dtype: float64

# %%
df_numerized.corr()
# Out:
#               name     genre      year  released     score     votes  \
# name      1.000000  0.009617  0.024435 -0.005896  0.014904  0.005215
# genre     0.009617  1.000000 -0.073026  0.021712  0.034041 -0.169847
# year      0.024435 -0.073026  1.000000 -0.001481  0.055234  0.315880
# released -0.005896  0.021712 -0.001481  1.000000  0.046345  0.025136
# score     0.014904  0.034041  0.055234  0.046345  1.000000  0.516033
# votes     0.005215 -0.169847  0.315880  0.025136  0.516033  1.000000
# director  0.013699 -0.009303 -0.036936  0.003341  0.005569 -0.007523
# writer    0.011602  0.017500 -0.024568  0.008514  0.012827 -0.006613
# star     -0.007109  0.002619 -0.032770  0.015363  0.009041 -0.019946
# budget    0.022179 -0.382185  0.323066  0.002568  0.011730  0.450577
# gross     0.001088 -0.257183  0.350855 -0.025807  0.196416  0.657578
#
#           director    writer      star    budget     gross
# name      0.013699  0.011602 -0.007109  0.022179  0.001088
# ...

# %%
sorted_pair = corr_pair.sort_values()
high_corr= sorted_pair[(sorted_pair) > 0.5]
high_corr
# Out:
# votes     score       0.516033
# score     votes       0.516033
# votes     gross       0.657578
# gross     votes       0.657578
# budget    gross       0.696424
# gross     budget      0.696424
# name      name        1.000000
# votes     votes       1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# budget    budget      1.000000
# gross     gross       1.000000
# dtype: float64

# %% [markdown]
# the budget is highly correlated to the gross earnings the hypothesis was right
